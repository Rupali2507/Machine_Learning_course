# %% [markdown]
# # Seaborn Data Visualization
#
# Seaborn is a powerful Python library for creating informative and attractive statistical graphics. It is built on top of matplotlib and integrates closely with pandas data structures. Seaborn makes it easy to generate complex visualizations with just a few lines of code.
#
# **Key Features:**
# - High-level interface for drawing attractive statistical graphics
# - Built-in themes for improved aesthetics
# - Functions for visualizing univariate and bivariate distributions
# - Tools for fitting and visualizing linear regression models
# - Support for categorical variables and multi-plot grids
#
#
#
# Seaborn is ideal for quick exploration and visualization of data, making it a valuable tool in any data science workflow.

# %%
import seaborn as sns

# %%
#basic plotings

tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.title("Scatter Plot of Total Bill vs tip")
plt.show()

# %%
#line plot

sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("Line plot of total_bill vs size")
# Out:
# Text(0.5, 1.0, 'Line plot of total_bill vs size')

# %%
#categorical

sns.barplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
#box plot

sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## violin plot

sns.violinplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## kde plot

sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#pair plot

sns.pairplot(tips)

# %%
#heatmap

corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
sales_df=pd.read_csv('large_sales.csv')
sales_df
# Out:
#    Order ID        Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27  Customer 19   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19  North  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21  Customer 12  North  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01   Customer 2   West  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales
# 0        97.81      0.08      1079.82
# ...

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Category',y='Unit Price',data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Category', ylabel='Unit Price'>

# %%
plt.figure(figsize=(10,6))

sns.barplot(x='Region',y='Unit Price',data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Region', ylabel='Unit Price'>
