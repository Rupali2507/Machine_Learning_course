# %% [markdown]
# ## Data Manipulation and Analysis with pandas
#
# This section covers techniques and tools for manipulating and analyzing data using pandas, enabling you to extract insights and prepare datasets for further processing or visualization.

# %%
import pandas as pd

# %%
df = pd.read_csv('large_sales_with_missing.csv')

# %%
df
# Out:
#    Order ID        Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales
# 0        97.81       NaN      1079.82
# 1        65.76      0.04       505.04
# 2        13.21      0.23        10.17
# 3        33.13       NaN       317.05
# 4        65.48      0.25       491.10
# ..         ...       ...          ...
# 95       33.04      0.19       535.25
# 96       45.24      0.14       700.32
# 97       57.12      0.20       502.66
# 98       57.40      0.26       467.24
# 99       22.40      0.04        43.01
#
# [100 rows x 10 columns]

# %%
df.head(5)
# Out:
#   Order ID        Date     Customer Region   Product Category  Quantity  \
# 0  ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1  ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2  ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3  ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4  ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
#
#    Unit Price  Discount  Total Sales
# 0       97.81       NaN      1079.82
# 1       65.76      0.04       505.04
# 2       13.21      0.23        10.17
# 3       33.13       NaN       317.05
# 4       65.48      0.25       491.10

# %%
df.tail(5)
# Out:
#    Order ID        Date     Customer Region   Product Category  Quantity  \
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales
# 95       33.04      0.19       535.25
# 96       45.24      0.14       700.32
# 97       57.12      0.20       502.66
# 98       57.40      0.26       467.24
# 99       22.40      0.04        43.01

# %%
df.describe()
# Out:
#          Quantity  Unit Price   Discount  Total Sales
# count  100.000000  100.000000  90.000000   100.000000
# mean    10.870000   55.737200   0.166444   508.717500
# std      5.785134   24.687294   0.079511   365.486955
# min      1.000000   12.100000   0.010000    10.170000
# 25%      6.750000   33.505000   0.120000   227.465000
# 50%     11.000000   52.840000   0.160000   478.485000
# 75%     16.000000   72.827500   0.237500   717.637500
# max     20.000000   99.450000   0.290000  1705.910000

# %%
df.dtypes
# Out:
# Order ID        object
# Date            object
# Customer        object
# Region          object
# Product         object
# Category        object
# Quantity         int64
# Unit Price     float64
# Discount       float64
# Total Sales    float64
# dtype: object

# %%
## handling missing values
df.isnull()
# Out:
#     Order ID   Date  Customer  Region  Product  Category  Quantity  \
# 0      False  False      True   False    False     False     False
# 1      False  False     False   False    False     False     False
# 2      False  False     False   False    False     False     False
# 3      False  False     False   False    False     False     False
# 4      False  False     False    True    False     False     False
# ..       ...    ...       ...     ...      ...       ...       ...
# 95     False  False     False   False    False     False     False
# 96     False  False     False   False    False     False     False
# 97     False  False      True    True    False     False     False
# 98     False  False     False   False    False     False     False
# 99     False  False      True    True    False     False     False
#
#     Unit Price  Discount  Total Sales
# 0        False      True        False
# 1        False     False        False
# 2        False     False        False
# 3        False      True        False
# 4        False     False        False
# ..         ...       ...          ...
# 95       False     False        False
# 96       False     False        False
# 97       False     False        False
# 98       False     False        False
# 99       False     False        False
#
# [100 rows x 10 columns]

# %%
df.isnull().any()
# Out:
# Order ID       False
# Date           False
# Customer        True
# Region          True
# Product        False
# Category       False
# Quantity       False
# Unit Price     False
# Discount        True
# Total Sales    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Order ID        0
# Date            0
# Customer       10
# Region         10
# Product         0
# Category        0
# Quantity        0
# Unit Price      0
# Discount       10
# Total Sales     0
# dtype: int64

# %%
df_filled =df.fillna(0)

# %%
## fill missing values with mean of the column

df['Discount_fillNA']=df['Discount'].fillna(df['Discount'].mean())

df
# Out:
#    Order ID        Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales  Discount_fillNA
# 0        97.81       NaN      1079.82         0.166444
# 1        65.76      0.04       505.04         0.040000
# 2        13.21      0.23        10.17         0.230000
# 3        33.13       NaN       317.05         0.166444
# 4        65.48      0.25       491.10         0.250000
# ..         ...       ...          ...              ...
# 95       33.04      0.19       535.25         0.190000
# 96       45.24      0.14       700.32         0.140000
# 97       57.12      0.20       502.66         0.200000
# 98       57.40      0.26       467.24         0.260000
# 99       22.40      0.04        43.01         0.040000
#
# [100 rows x 11 columns]

# %%
df.dtypes
# Out:
# Order ID            object
# Date                object
# Customer            object
# Region              object
# Product             object
# Category            object
# Quantity             int64
# Unit Price         float64
# Discount           float64
# Total Sales        float64
# Discount_fillNA    float64
# dtype: object

# %%
## renaming columns

df =df.rename(columns={'Date':'Sale Date'})
df.head()
# Out:
#   Order ID   Sale Date     Customer Region   Product Category  Quantity  \
# 0  ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1  ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2  ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3  ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4  ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
#
#    Unit Price  Discount  Total Sales  Discount_fillNA
# 0       97.81       NaN      1079.82         0.166444
# 1       65.76      0.04       505.04         0.040000
# 2       13.21      0.23        10.17         0.230000
# 3       33.13       NaN       317.05         0.166444
# 4       65.48      0.25       491.10         0.250000

# %%
df =df.rename(columns={'Sale Date':'Sales Date'})
df.head()
# Out:
#   Order ID  Sales Date     Customer Region   Product Category  Quantity  \
# 0  ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1  ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2  ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3  ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4  ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
#
#    Unit Price  Discount  Total Sales  Discount_fillNA
# 0       97.81       NaN      1079.82         0.166444
# 1       65.76      0.04       505.04         0.040000
# 2       13.21      0.23        10.17         0.230000
# 3       33.13       NaN       317.05         0.166444
# 4       65.48      0.25       491.10         0.250000

# %%
#change dataTypes

df.dtypes
# Out:
# Order ID            object
# Sales Date          object
# Customer            object
# Region              object
# Product             object
# Category            object
# Quantity             int64
# Unit Price         float64
# Discount           float64
# Total Sales        float64
# Discount_fillNA    float64
# dtype: object

# %%
df['Quantity_new']=df['Quantity'].astype(float)

# %%
df.dtypes
# Out:
# Order ID            object
# Sales Date          object
# Customer            object
# Region              object
# Product             object
# Category            object
# Quantity             int64
# Unit Price         float64
# Discount           float64
# Total Sales        float64
# Discount_fillNA    float64
# Quantity_new       float64
# dtype: object

# %%
df
# Out:
#    Order ID  Sales Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales  Discount_fillNA  Quantity_new
# 0        97.81       NaN      1079.82         0.166444          12.0
# 1        65.76      0.04       505.04         0.040000           8.0
# 2        13.21      0.23        10.17         0.230000           1.0
# 3        33.13       NaN       317.05         0.166444          11.0
# 4        65.48      0.25       491.10         0.250000          10.0
# ..         ...       ...          ...              ...           ...
# 95       33.04      0.19       535.25         0.190000          20.0
# 96       45.24      0.14       700.32         0.140000          18.0
# 97       57.12      0.20       502.66         0.200000          11.0
# 98       57.40      0.26       467.24         0.260000          11.0
# 99       22.40      0.04        43.01         0.040000           2.0
#
# [100 rows x 12 columns]

# %%
df['New_Discount']=df['Discount'].fillna(df['Discount'].mean()).astype(int)

# %%
df
# Out:
#    Order ID  Sales Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales  Discount_fillNA  Quantity_new  \
# 0        97.81       NaN      1079.82         0.166444          12.0
# 1        65.76      0.04       505.04         0.040000           8.0
# 2        13.21      0.23        10.17         0.230000           1.0
# 3        33.13       NaN       317.05         0.166444          11.0
# 4        65.48      0.25       491.10         0.250000          10.0
# ..         ...       ...          ...              ...           ...
# 95       33.04      0.19       535.25         0.190000          20.0
# 96       45.24      0.14       700.32         0.140000          18.0
# 97       57.12      0.20       502.66         0.200000          11.0
# 98       57.40      0.26       467.24         0.260000          11.0
# 99       22.40      0.04        43.01         0.040000           2.0
#
#     New_Discount
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0
# ..           ...
# 95             0
# 96             0
# 97             0
# 98             0
# 99             0
#
# [100 rows x 13 columns]

# %%
df['New Discount']=df['Discount'].apply(lambda x:x*10)

# %%
df
# Out:
#    Order ID  Sales Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales  Discount_fillNA  Quantity_new  \
# 0        97.81       NaN      1079.82         0.166444          12.0
# 1        65.76      0.04       505.04         0.040000           8.0
# 2        13.21      0.23        10.17         0.230000           1.0
# 3        33.13       NaN       317.05         0.166444          11.0
# 4        65.48      0.25       491.10         0.250000          10.0
# ..         ...       ...          ...              ...           ...
# 95       33.04      0.19       535.25         0.190000          20.0
# 96       45.24      0.14       700.32         0.140000          18.0
# 97       57.12      0.20       502.66         0.200000          11.0
# 98       57.40      0.26       467.24         0.260000          11.0
# 99       22.40      0.04        43.01         0.040000           2.0
#
#     New_Discount  New Discount
# 0              0           NaN
# 1              0           0.4
# 2              0           2.3
# 3              0           NaN
# 4              0           2.5
# ..           ...           ...
# 95             0           1.9
# 96             0           1.4
# 97             0           2.0
# 98             0           2.6
# 99             0           0.4
#
# [100 rows x 14 columns]

# %%
df['New_Discount']=df['New Discount'].fillna(df['New Discount'].mean()).astype(int)

# %%
df
# Out:
#    Order ID  Sales Date     Customer Region   Product Category  Quantity  \
# 0   ORD0001  2024-04-27          NaN   West  Widget C  Widgets        12
# 1   ORD0002  2024-05-28   Customer 3   West  Widget B  Widgets         8
# 2   ORD0003  2024-04-06  Customer 19  North  Gadget B  Gadgets         1
# 3   ORD0004  2024-06-25   Customer 7  South  Gadget A  Gadgets        11
# 4   ORD0005  2024-05-17  Customer 19    NaN  Widget C  Widgets        10
# ..      ...         ...          ...    ...       ...      ...       ...
# 95  ORD0096  2024-02-15   Customer 3   West  Widget A  Widgets        20
# 96  ORD0097  2024-03-23  Customer 16   West  Gadget B  Gadgets        18
# 97  ORD0098  2024-01-21          NaN    NaN  Gadget B  Gadgets        11
# 98  ORD0099  2024-03-31  Customer 12   East  Gadget B  Gadgets        11
# 99  ORD0100  2024-04-01          NaN    NaN  Widget C  Widgets         2
#
#     Unit Price  Discount  Total Sales  Discount_fillNA  Quantity_new  \
# 0        97.81       NaN      1079.82         0.166444          12.0
# 1        65.76      0.04       505.04         0.040000           8.0
# 2        13.21      0.23        10.17         0.230000           1.0
# 3        33.13       NaN       317.05         0.166444          11.0
# 4        65.48      0.25       491.10         0.250000          10.0
# ..         ...       ...          ...              ...           ...
# 95       33.04      0.19       535.25         0.190000          20.0
# 96       45.24      0.14       700.32         0.140000          18.0
# 97       57.12      0.20       502.66         0.200000          11.0
# 98       57.40      0.26       467.24         0.260000          11.0
# 99       22.40      0.04        43.01         0.040000           2.0
#
#     New_Discount  New Discount
# 0              1           NaN
# 1              0           0.4
# 2              2           2.3
# 3              1           NaN
# 4              2           2.5
# ..           ...           ...
# 95             1           1.9
# 96             1           1.4
# 97             2           2.0
# 98             2           2.6
# 99             0           0.4
#
# [100 rows x 14 columns]

# %%
## data aggregating and grouping
groupped_mean = df.groupby('Quantity')['Unit Price'].mean()

# %%
print(groupped_mean)
# Out:
# Quantity
# 1     46.980000
# 2     33.888000
# 3     65.668000
# 4     53.287500
# 5     70.850000
# 6     61.357500
# 7     96.330000
# 8     48.911250
# 9     59.737143
# 10    71.576000
# 11    61.418000
# 12    57.374000
# 13    59.882500
# 14    54.295000
# 15    49.970000
# 16    41.662000
# 17    79.880000
# 18    53.047778
# 19    51.357500
# 20    52.086667
# Name: Unit Price, dtype: float64

# %%
sum(groupped_mean)
# Out:
# 1169.5588373015873

# %%
groupped_mean_I = df.groupby('Product')['Quantity'].mean()

# %%
print(groupped_mean_I)
# Out:
# Product
# Gadget A    12.818182
# Gadget B    10.411765
# Widget A    11.736842
# Widget B     9.437500
# Widget C     9.769231
# Name: Quantity, dtype: float64

# %%
groupped_mean_II = df.groupby(['Product','Region'])['Quantity'].mean()

# %%
groupped_mean_II
# Out:
# Product   Region
# Gadget A  East      14.500000
#           North     14.000000
#           South      8.600000
#           West      13.142857
# Gadget B  East       7.666667
#           North      7.400000
#           South     14.000000
#           West      16.333333
# Widget A  East       9.500000
#           North     12.000000
#           South     10.800000
#           West      12.400000
# Widget B  East       8.333333
#           North     11.166667
#           South      8.000000
#           West       9.500000
# Widget C  East      10.285714
#           North     12.250000
#           South      7.000000
#           West      10.222222
# Name: Quantity, dtype: float64

# %%
## aggregate multiple functions
grouped_agg = df.groupby('Region')['Quantity'].agg(['mean','sum','count'])

# %%
grouped_agg
# Out:
#              mean  sum  count
# Region
# East    10.368421  197     19
# North   11.291667  271     24
# South    9.857143  207     21
# West    12.076923  314     26

# %%
#Merging and joining DataFrames

# create sample dataframes

df1 = pd.DataFrame({'Key':['A', 'B', 'C'],'Value1':[1,2,3]})
df2 = pd.DataFrame({'Key':['A', 'B', 'D'],'Value2':[4,5,6]})

# %%
df1
# Out:
#   Key  Value1
# 0   A       1
# 1   B       2
# 2   C       3

# %%
df2
# Out:
#   Key  Value2
# 0   A       4
# 1   B       5
# 2   D       6

# %%
pd.merge(df1,df2,on="Key",how="inner")
# Out:
#   Key  Value1  Value2
# 0   A       1       4
# 1   B       2       5

# %%
pd.merge(df1,df2,on="Key",how="outer")
# Out:
#   Key  Value1  Value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0

# %%
pd.merge(df1,df2,on="Key",how="left")
# Out:
#   Key  Value1  Value2
# 0   A       1     4.0
# 1   B       2     5.0
# 2   C       3     NaN

# %%
pd.merge(df1,df2,on="Key",how="right")
# Out:
#   Key  Value1  Value2
# 0   A     1.0       4
# 1   B     2.0       5
# 2   D     NaN       6
